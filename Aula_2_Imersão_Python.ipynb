# %% [markdown]
# <a href="https://colab.research.google.com/github/ElcioLS/-/blob/main/Aula_2_Imers%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 2 - Importação

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Aula 2 - Imersão Python - Tabela de ações.xlsx", sheet_name="Principal")
df_principal.head(10)
# Out:
#    Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0  USIM5 2024-01-26         9.50          5.20          11.76          2.26
# 1  CMIN3 2024-01-26         6.82          2.40           2.40        -12.11
# 2  PETR3 2024-01-26        41.96          2.19           7.73          7.64
# 3  SUZB3 2024-01-26        52.91          2.04           2.14         -4.89
# 4  CPFE3 2024-01-26        37.10          2.03           2.49         -3.66
# 5  PRIO3 2024-01-26        45.69          1.98           2.42         -0.78
# 6  PETR4 2024-01-26        39.96          1.73           6.47          7.30
# 7  VALE3 2024-01-26        69.50          1.66           2.06         -9.97
# 8  MULT3 2024-01-26        28.19          1.58           2.03         -0.81
# 9  ITUB4 2024-01-26        32.81          1.48          -0.39         -3.36
#
#    Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx  ... Quantidade de ações  \
# 0          2.26         15.97      9.18      9.56  ...           515117391
# 1        -12.11         50.56      6.66      6.86  ...          1110559345
# 2          7.64         77.55     40.81     42.34  ...          2379877655
# 3         -4.89         18.85     51.89     53.17  ...           683452836
# 4         -3.66         20.70     36.37     37.32  ...           187732538
# 5         -0.78          8.08     44.25     45.69  ...           800010734
# 6          7.30         95.01     38.91     40.09  ...          4566445852
# 7         -9.97        -23.49     67.50     69.81  ...          4196924316
# 8         -0.81         24.02     27.71     28.36  ...           268505432
# 9         -3.36         34.25     32.35     32.91  ...          4801593832
#
#      Variação $  Resultado  Variação Semanal  Variação Mensal  \
# 0  2.418897e+08      Subiu            0.1176           0.0226
# 1  1.775160e+08      Subiu            0.0240          -0.1211
# 2  2.140059e+09      Subiu            0.0773           0.0764
# 3  7.229463e+08      Subiu            0.0214          -0.0489
# 4  1.385740e+08      Subiu            0.0249          -0.0366
# 5  7.096875e+08      Subiu            0.0242          -0.0078
# 6  3.103136e+09      Subiu            0.0647           0.0730
# 7  4.762927e+09      Subiu            0.0206          -0.0997
# 8  1.177327e+08      Subiu            0.0203          -0.0081
# 9  2.297592e+09      Subiu           -0.0039          -0.0336
#
#   Variação 12 meses  Nome da Empresa                Segmento  Idade  \
# 0            0.1597         Usiminas              Siderurgia     70
# 1            0.5056    CSN Mineração               Mineração      8
# 2            0.7755        Petrobras          Petróleo e Gás     68
# 3            0.1885           Suzano        Papel e Celulose     97
# 4            0.2070     CPFL Energia        Energia Elétrica    109
# 5            0.0808         PetroRio          Petróleo e Gás     68
# 6            0.9501        Petrobras          Petróleo e Gás     68
# 7           -0.2349             Vale               Mineração      8
# 8            0.2402        Multiplan        Shopping Centers     48
# 9            0.3425    Itaú Unibanco  Instituição Financeira     18
#
#     Categoria Idade
# 0    Entre 50 e 100
# 1  Menos de 50 anos
# 2    Entre 50 e 100
# 3    Entre 50 e 100
# 4  Mais de 100 anos
# 5    Entre 50 e 100
# 6    Entre 50 e 100
# 7  Menos de 50 anos
# 8  Menos de 50 anos
# 9  Menos de 50 anos
#
# [10 rows x 23 columns]

# %%
df_principal = df_principal[['']]

# %%
df_total_acoes = pd.read_excel("/content/Aula 2 - Imersão Python - Tabela de ações.xlsx", sheet_name="Total_de_acoes")
df_total_acoes.head(10)
# Out:
#   Código  Qtde. Teórica
# 0  RRRP3   2.356656e+08
# 1  ALOS3   5.326166e+08
# 2  ALPA4   1.767340e+08
# 3  ABEV3   4.394246e+09
# 4  ARZZ3   6.230589e+07
# 5  ASAI3   1.349218e+09
# 6  AZUL4   3.275937e+08
# 7  B3SA3   5.602790e+09
# 8  BBSE3   6.717508e+08
# 9  BBDC3   1.500729e+09

# %%
df_ticker = pd.read_excel("/content/Aula 2 - Imersão Python - Tabela de ações.xlsx", sheet_name="Ticker")
df_ticker.head(10)
# Out:
#   Ticker            Nome
# 0  MGLU3  Magazine Luiza
# 1  HAPV3         Hapvida
# 2  PETR4       Petrobras
# 3  B3SA3              B3
# 4  USIM5        Usiminas
# 5  CVCB3             CVC
# 6  CIEL3           Cielo
# 7  VALE3            Vale
# 8  GOLL4             GOL
# 9  BBDC4  Banco Bradesco

# %%
df_chatGpt = pd.read_excel("/content/Aula 2 - Imersão Python - Tabela de ações.xlsx", sheet_name="chatGpt")
df_chatGpt.head(10)
# Out:
#   Nome da Empresa                Segmento  Idade (em anos)
# 0        Usiminas              Siderurgia               70
# 1   CSN Mineração               Mineração                8
# 2       Petrobras          Petróleo e Gás               68
# 3          Suzano        Papel e Celulose               97
# 4    CPFL Energia        Energia Elétrica              109
# 5        PetroRio          Petróleo e Gás               12
# 6            Vale               Mineração               79
# 7       Multiplan        Shopping Centers               48
# 8   Itaú Unibanco  Instituição Financeira               18
# 9       Rede D'Or                   Saúde               15

# %%
df_principal = df_principal[['Ativo',	'Data',	'Último (R$)',	'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0   USIM5 2024-01-26         9.50          5.20
# 1   CMIN3 2024-01-26         6.82          2.40
# 2   PETR3 2024-01-26        41.96          2.19
# 3   SUZB3 2024-01-26        52.91          2.04
# 4   CPFE3 2024-01-26        37.10          2.03
# ..    ...        ...          ...           ...
# 76  CRFB3 2024-01-26        10.71         -2.45
# 77  BHIA3 2024-01-26         8.70         -2.46
# 78  RENT3 2024-01-26        56.24         -3.63
# 79  CVCB3 2024-01-26         3.07         -4.36
# 80  GOLL4 2024-01-26         5.92         -8.07
#
# [81 rows x 4 columns]

# %%
df_principal = df_principal.rename(columns={'Último (R$)':'valor_final','Var. Dia (%)':'var_dia_pct'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] /100
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct
# 0   USIM5 2024-01-26         9.50         5.20   0.0520
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240
# 2   PETR3 2024-01-26        41.96         2.19   0.0219
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203
# ..    ...        ...          ...          ...      ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807
#
# [81 rows x 5 columns]

# %%
df_principal['Var_pct'] = df_principal['var_dia_pct'] /100
df_principal['valor_inicial'] = df_principal['valor_final'] /(df_principal['Var_pct'] + 1)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
# [81 rows x 6 columns]

# %%
df_principal['Variacao_rs'] = (df_principal['valor_final'] - df_principal['valor_inicial'])*df_principal['Qtde. Teórica']
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica   Variacao_rs
# 0    5.151174e+08  2.418897e+08
# 1    1.110559e+09  1.775160e+08
# 2    2.379878e+09  2.140059e+09
# 3    6.834528e+08  7.229463e+08
# 4    1.877325e+08  1.385740e+08
# ..            ...           ...
# 76   5.339906e+08 -1.436355e+08
# 77   9.484305e+07 -2.081024e+07
# 78   8.532023e+08 -1.807433e+09
# 79   5.255828e+08 -7.355741e+07
# 80   1.981849e+08 -1.029932e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.merge(df_total_acoes, left_on='Ativo', right_on='Código', how='left')
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial Código  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418  USIM5
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156  CMIN3
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769  PETR3
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215  SUZB3
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854  CPFE3
# ..    ...        ...          ...          ...      ...            ...    ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985  CRFB3
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418  BHIA3
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410  RENT3
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954  CVCB3
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682  GOLL4
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.drop(columns=['Código'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20   0.0520       9.030418
# 1   CMIN3 2024-01-26         6.82         2.40   0.0240       6.660156
# 2   PETR3 2024-01-26        41.96         2.19   0.0219      41.060769
# 3   SUZB3 2024-01-26        52.91         2.04   0.0204      51.852215
# 4   CPFE3 2024-01-26        37.10         2.03   0.0203      36.361854
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45  -0.0245      10.978985
# 77  BHIA3 2024-01-26         8.70        -2.46  -0.0246       8.919418
# 78  RENT3 2024-01-26        56.24        -3.63  -0.0363      58.358410
# 79  CVCB3 2024-01-26         3.07        -4.36  -0.0436       3.209954
# 80  GOLL4 2024-01-26         5.92        -8.07  -0.0807       6.439682
#
#     Qtde. Teórica
# 0    5.151174e+08
# 1    1.110559e+09
# 2    2.379878e+09
# 3    6.834528e+08
# 4    1.877325e+08
# ..            ...
# 76   5.339906e+08
# 77   9.484305e+07
# 78   8.532023e+08
# 79   5.255828e+08
# 80   1.981849e+08
#
# [81 rows x 7 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0    515117391.00   241889725.43
# 1   1110559345.00   177515970.30
# 2   2379877655.00  2140059393.53
# 3    683452836.00   722946282.71
# 4    187732538.00   138573955.06
# ..            ...            ...
# 76   533990587.00  -143635530.57
# 77    94843047.00   -20810240.84
# 78   853202347.00 -1807432634.46
# 79   525582771.00   -73557408.06
# 80   198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Qtde. Teórica'] = df_principal['Qtde. Teórica'].astype(int)
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtde. Teórica    Variacao_rs
# 0       515117391   241889725.43
# 1      1110559345   177515970.30
# 2      2379877655  2140059393.53
# 3       683452836   722946282.71
# 4       187732538   138573955.06
# ..            ...            ...
# 76      533990587  -143635530.57
# 77       94843047   -20810240.84
# 78      853202347 -1807432634.46
# 79      525582771   -73557408.06
# 80      198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs
# 0     515117391   241889725.43
# 1    1110559345   177515970.30
# 2    2379877655  2140059393.53
# 3     683452836   722946282.71
# 4     187732538   138573955.06
# ..          ...            ...
# 76    533990587  -143635530.57
# 77     94843047   -20810240.84
# 78    853202347 -1807432634.46
# 79    525582771   -73557408.06
# 80    198184909  -102993202.62
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado'] = df_principal['Variacao_rs'].apply(lambda x: "Subiu" if x > 0 else ("Desceu" if x < 0 else "Estável"))

# %%
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado
# 0     515117391   241889725.43     Subiu
# 1    1110559345   177515970.30     Subiu
# 2    2379877655  2140059393.53     Subiu
# 3     683452836   722946282.71     Subiu
# 4     187732538   138573955.06     Subiu
# ..          ...            ...       ...
# 76    533990587  -143635530.57    Desceu
# 77     94843047   -20810240.84    Desceu
# 78    853202347 -1807432634.46    Desceu
# 79    525582771   -73557408.06    Desceu
# 80    198184909  -102993202.62    Desceu
#
# [81 rows x 9 columns]

# %%
df_principal = df_principal.merge(df_ticker, left_on='Ativo', right_on='Ticker', how='left')
# df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado Ticker_x            Nome_x Ticker_y  \
# 0     515117391   241889725.43     Subiu    USIM5          Usiminas    USIM5
# 1    1110559345   177515970.30     Subiu    CMIN3     CSN Mineração    CMIN3
# 2    2379877655  2140059393.53     Subiu    PETR3         Petrobras    PETR3
# 3     683452836   722946282.71     Subiu    SUZB3            Suzano    SUZB3
# 4     187732538   138573955.06     Subiu    CPFE3      CPFL Energia    CPFE3
# ..          ...            ...       ...      ...               ...      ...
# 76    533990587  -143635530.57    Desceu    CRFB3  Carrefour Brasil    CRFB3
# 77     94843047   -20810240.84    Desceu    BHIA3       Casas Bahia    BHIA3
# 78    853202347 -1807432634.46    Desceu    RENT3          Localiza    RENT3
# 79    525582771   -73557408.06    Desceu    CVCB3               CVC    CVCB3
# 80    198184909  -102993202.62    Desceu    GOLL4               GOL    GOLL4
#
#               Nome_y Ticker              Nome
# 0           Usiminas  USIM5          Usiminas
# 1      CSN Mineração  CMIN3     CSN Mineração
# 2          Petrobras  PETR3         Petrobras
# 3             Suzano  SUZB3            Suzano
# 4       CPFL Energia  CPFE3      CPFL Energia
# ..               ...    ...               ...
# 76  Carrefour Brasil  CRFB3  Carrefour Brasil
# 77       Casas Bahia  BHIA3       Casas Bahia
# 78          Localiza  RENT3          Localiza
# 79               CVC  CVCB3               CVC
# 80               GOL  GOLL4               GOL
#
# [81 rows x 15 columns]

# %%
df_principal = df_principal.drop(columns=['Ticker'])
df_principal
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-20e8d59a2fcc> in <cell line: 1>()
# ----> 1 df_principal = df_principal.drop(columns=['Ticker'])
#       2 df_principal
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['Ticker'] not found in axis"

# %%
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado Ticker_x            Nome_x Ticker_y  \
# 0     515117391   241889725.43     Subiu    USIM5          Usiminas    USIM5
# 1    1110559345   177515970.30     Subiu    CMIN3     CSN Mineração    CMIN3
# 2    2379877655  2140059393.53     Subiu    PETR3         Petrobras    PETR3
# 3     683452836   722946282.71     Subiu    SUZB3            Suzano    SUZB3
# 4     187732538   138573955.06     Subiu    CPFE3      CPFL Energia    CPFE3
# ..          ...            ...       ...      ...               ...      ...
# 76    533990587  -143635530.57    Desceu    CRFB3  Carrefour Brasil    CRFB3
# 77     94843047   -20810240.84    Desceu    BHIA3       Casas Bahia    BHIA3
# 78    853202347 -1807432634.46    Desceu    RENT3          Localiza    RENT3
# 79    525582771   -73557408.06    Desceu    CVCB3               CVC    CVCB3
# 80    198184909  -102993202.62    Desceu    GOLL4               GOL    GOLL4
#
#               Nome_y              Nome
# 0           Usiminas          Usiminas
# 1      CSN Mineração     CSN Mineração
# 2          Petrobras         Petrobras
# 3             Suzano            Suzano
# 4       CPFL Energia      CPFL Energia
# ..               ...               ...
# 76  Carrefour Brasil  Carrefour Brasil
# 77       Casas Bahia       Casas Bahia
# 78          Localiza          Localiza
# 79               CVC               CVC
# 80               GOL               GOL
#
# [81 rows x 14 columns]

# %%
df_principal = df_principal.merge(df_chatGpt, left_on='Nome', right_on='Nome da Empresa',how='left')
df_principal = df_principal.drop(columns=['Nome da Empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado Ticker_x            Nome_x Ticker_y  \
# 0     515117391   241889725.43     Subiu    USIM5          Usiminas    USIM5
# 1    1110559345   177515970.30     Subiu    CMIN3     CSN Mineração    CMIN3
# 2    2379877655  2140059393.53     Subiu    PETR3         Petrobras    PETR3
# 3     683452836   722946282.71     Subiu    SUZB3            Suzano    SUZB3
# 4     187732538   138573955.06     Subiu    CPFE3      CPFL Energia    CPFE3
# ..          ...            ...       ...      ...               ...      ...
# 76    533990587  -143635530.57    Desceu    CRFB3  Carrefour Brasil    CRFB3
# 77     94843047   -20810240.84    Desceu    BHIA3       Casas Bahia    BHIA3
# 78    853202347 -1807432634.46    Desceu    RENT3          Localiza    RENT3
# 79    525582771   -73557408.06    Desceu    CVCB3               CVC    CVCB3
# 80    198184909  -102993202.62    Desceu    GOLL4               GOL    GOLL4
#
#               Nome_y              Nome           Segmento  Idade (em anos)
# 0           Usiminas          Usiminas         Siderurgia               70
# 1      CSN Mineração     CSN Mineração          Mineração                8
# 2          Petrobras         Petrobras     Petróleo e Gás               68
# 3             Suzano            Suzano   Papel e Celulose               97
# 4       CPFL Energia      CPFL Energia   Energia Elétrica              109
# ..               ...               ...                ...              ...
# 76  Carrefour Brasil  Carrefour Brasil             Varejo               68
# 77       Casas Bahia       Casas Bahia             Varejo               96
# 78          Localiza          Localiza  Aluguel de Carros               49
# 79               CVC               CVC            Turismo               49
# 80               GOL               GOL   Transporte Aéreo               23
#
# [81 rows x 16 columns]

# %%
df_principal['Categoria Idade'] = df_principal['Idade (em anos)'].apply(lambda x: "Mais de 100 anos" if x > 100 else ("Menos de 50 anos" if x < 50 else "Entre 50 e 100"))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# ..    ...        ...          ...          ...      ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45    -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46    -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63    -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36    -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07    -0.08           6.44
#
#     Qtd_teorica    Variacao_rs Resultado Ticker_x            Nome_x Ticker_y  \
# 0     515117391   241889725.43     Subiu    USIM5          Usiminas    USIM5
# 1    1110559345   177515970.30     Subiu    CMIN3     CSN Mineração    CMIN3
# 2    2379877655  2140059393.53     Subiu    PETR3         Petrobras    PETR3
# 3     683452836   722946282.71     Subiu    SUZB3            Suzano    SUZB3
# 4     187732538   138573955.06     Subiu    CPFE3      CPFL Energia    CPFE3
# ..          ...            ...       ...      ...               ...      ...
# 76    533990587  -143635530.57    Desceu    CRFB3  Carrefour Brasil    CRFB3
# 77     94843047   -20810240.84    Desceu    BHIA3       Casas Bahia    BHIA3
# 78    853202347 -1807432634.46    Desceu    RENT3          Localiza    RENT3
# 79    525582771   -73557408.06    Desceu    CVCB3               CVC    CVCB3
# 80    198184909  -102993202.62    Desceu    GOLL4               GOL    GOLL4
#
#               Nome_y              Nome           Segmento  Idade (em anos)  \
# 0           Usiminas          Usiminas         Siderurgia               70
# 1      CSN Mineração     CSN Mineração          Mineração                8
# 2          Petrobras         Petrobras     Petróleo e Gás               68
# 3             Suzano            Suzano   Papel e Celulose               97
# 4       CPFL Energia      CPFL Energia   Energia Elétrica              109
# ..               ...               ...                ...              ...
# 76  Carrefour Brasil  Carrefour Brasil             Varejo               68
# 77       Casas Bahia       Casas Bahia             Varejo               96
# 78          Localiza          Localiza  Aluguel de Carros               49
# 79               CVC               CVC            Turismo               49
# 80               GOL               GOL   Transporte Aéreo               23
#
#      Categoria Idade
# 0     Entre 50 e 100
# 1   Menos de 50 anos
# 2     Entre 50 e 100
# 3     Entre 50 e 100
# 4   Mais de 100 anos
# ..               ...
# 76    Entre 50 e 100
# 77    Entre 50 e 100
# 78  Menos de 50 anos
# 79  Menos de 50 anos
# 80  Menos de 50 anos
#
# [81 rows x 17 columns]

# %%
maior = df_principal['Variacao_rs'].max()
menor = df_principal['Variacao_rs'].min()
media = df_principal['Variacao_rs'].mean()

media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Exibindo os resultados
print("Maior\t", "{:,.2f}".format(maior))
print("Menor\t", "{:,.2f}".format(menor))
print("Média\t", "{:,.2f}".format(media))
print("Média dos que subiram\t", "{:,.2f}".format(media_subiu))
print("Média dos que desceram\t", "{:,.2f}".format(media_desceu))
# Out:
# Maior	 4,762,926,995.25
# Menor	 -1,807,432,634.46
# Média	 165,190,210.48
# Média dos que subiram	 448,164,250.23
# Média dos que desceram	 -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 5   PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 6   PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 7   VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 8   MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 9   ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 10  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 11  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 12  AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 13  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 14  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 15  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 16  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
# 17  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 18  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 19  ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 20  BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 21  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 22  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 23  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 24  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 25  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 26  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 27  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 28  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 29  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 30  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 31  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 32  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 33  BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 34  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 35  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 36  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 37  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 38  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 39  BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 40  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 41  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 42  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 43  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
#
#     Qtd_teorica   Variacao_rs Resultado Ticker_x                Nome_x  \
# 0     515117391  241889725.43     Subiu    USIM5              Usiminas
# 1    1110559345  177515970.30     Subiu    CMIN3         CSN Mineração
# 2    2379877655 2140059393.53     Subiu    PETR3             Petrobras
# 3     683452836  722946282.71     Subiu    SUZB3                Suzano
# 4     187732538  138573955.06     Subiu    CPFE3          CPFL Energia
# 5     800010734  709687498.18     Subiu    PRIO3              PetroRio
# 6    4566445852 3103136291.22     Subiu    PETR4             Petrobras
# 7    4196924316 4762926995.25     Subiu    VALE3                  Vale
# 8     268505432  117732680.08     Subiu    MULT3             Multiplan
# 9    4801593832 2297591984.33     Subiu    ITUB4         Itaú Unibanco
# 10   1168230366  453917907.01     Subiu    RDOR3             Rede D'Or
# 11    265877867   69054317.64     Subiu    BRKM5               Braskem
# 12    327593725   65452205.55     Subiu    AZUL4                  Azul
# 13    235665566   94204643.35     Subiu    RRRP3          3R Petroleum
# 14   1095587251  511671895.45     Subiu    EQTL3    Equatorial Energia
# 15    600865451  143220991.46     Subiu    CSNA3  Siderúrgica Nacional
# 16    289347914   72295838.99     Subiu    YDUQ3                 YDUQS
# 17   1086411192  388705223.96     Subiu    UGPA3              Ultrapar
# 18    376187582   37525872.38     Subiu    MRVE3                   MRV
# 19     62305891   41021792.09     Subiu    ARZZ3                Arezzo
# 20   5146576868  822148336.41     Subiu    BBDC4        Banco Bradesco
# 21    261036182   18214628.10     Subiu    BEEF3               Minerva
# 22    159430826    6340916.22     Subiu    PCAR3   Grupo Pão de Açúcar
# 23   1677525446  233045769.57     Subiu    BRFS3                   BRF
# 24    423091712  188965307.06     Subiu    VIVT3                  Vivo
# 25   1218352541  229771333.63     Subiu    RAIL3                  Rumo
# 26   1095462329   43657683.38     Subiu    CIEL3                 Cielo
# 27    302768240   18068446.61     Subiu    DXCO3                 Dexco
# 28    807896814  103972807.37     Subiu    TIMS3                   TIM
# 29    251003438   42238249.54     Subiu    BRAP4             Bradespar
# 30    393173139   15598886.65     Subiu    LWSA3               Locaweb
# 31    275005663   46201006.00     Subiu    RECV3        PetroRecôncavo
# 32   5372783971  373853994.88     Subiu    ITSA4                Itaúsa
# 33   1420949112  546752087.99     Subiu    BBAS3       Banco do Brasil
# 34   1275798515  202352473.74     Subiu    RADL3          RaiaDrogasil
# 35    660411219   39045606.94     Subiu    GOAU4    Metalúrgica Gerdau
# 36   1168097881  127229653.18     Subiu    CSAN3                 Cosan
# 37   1134986472  156573285.43     Subiu    JBSS3                   JBS
# 38   2867627068   28493619.27     Subiu    MGLU3        Magazine Luiza
# 39   1500728902   74019610.05     Subiu    BBDC3        Banco Bradesco
# 40   1118525506   65779607.10     Subiu    GGBR4                Gerdau
# 41   1193047233   11571106.42     Subiu    RAIZ4                Raízen
# 42   1679335290   32069789.50     Subiu    CPLE6                 Copel
# 43    421383330    4131341.16     Subiu    VAMO3           Grupo Vamos
#
#    Ticker_y                Nome_y                  Nome  \
# 0     USIM5              Usiminas              Usiminas
# 1     CMIN3         CSN Mineração         CSN Mineração
# 2     PETR3             Petrobras             Petrobras
# 3     SUZB3                Suzano                Suzano
# 4     CPFE3          CPFL Energia          CPFL Energia
# 5     PRIO3              PetroRio              PetroRio
# 6     PETR4             Petrobras             Petrobras
# 7     VALE3                  Vale                  Vale
# 8     MULT3             Multiplan             Multiplan
# 9     ITUB4         Itaú Unibanco         Itaú Unibanco
# 10    RDOR3             Rede D'Or             Rede D'Or
# 11    BRKM5               Braskem               Braskem
# 12    AZUL4                  Azul                  Azul
# 13    RRRP3          3R Petroleum          3R Petroleum
# 14    EQTL3    Equatorial Energia    Equatorial Energia
# 15    CSNA3  Siderúrgica Nacional  Siderúrgica Nacional
# 16    YDUQ3                 YDUQS                 YDUQS
# 17    UGPA3              Ultrapar              Ultrapar
# 18    MRVE3                   MRV                   MRV
# 19    ARZZ3                Arezzo                Arezzo
# 20    BBDC4        Banco Bradesco        Banco Bradesco
# 21    BEEF3               Minerva               Minerva
# 22    PCAR3   Grupo Pão de Açúcar   Grupo Pão de Açúcar
# 23    BRFS3                   BRF                   BRF
# 24    VIVT3                  Vivo                  Vivo
# 25    RAIL3                  Rumo                  Rumo
# 26    CIEL3                 Cielo                 Cielo
# 27    DXCO3                 Dexco                 Dexco
# 28    TIMS3                   TIM                   TIM
# 29    BRAP4             Bradespar             Bradespar
# 30    LWSA3               Locaweb               Locaweb
# 31    RECV3        PetroRecôncavo        PetroRecôncavo
# 32    ITSA4                Itaúsa                Itaúsa
# 33    BBAS3       Banco do Brasil       Banco do Brasil
# 34    RADL3          RaiaDrogasil          RaiaDrogasil
# 35    GOAU4    Metalúrgica Gerdau    Metalúrgica Gerdau
# 36    CSAN3                 Cosan                 Cosan
# 37    JBSS3                   JBS                   JBS
# 38    MGLU3        Magazine Luiza        Magazine Luiza
# 39    BBDC3        Banco Bradesco        Banco Bradesco
# 40    GGBR4                Gerdau                Gerdau
# 41    RAIZ4                Raízen                Raízen
# 42    CPLE6                 Copel                 Copel
# 43    VAMO3           Grupo Vamos           Grupo Vamos
#
#                   Segmento  Idade (em anos)   Categoria Idade
# 0               Siderurgia               70    Entre 50 e 100
# 1                Mineração                8  Menos de 50 anos
# 2           Petróleo e Gás               68    Entre 50 e 100
# 3         Papel e Celulose               97    Entre 50 e 100
# 4         Energia Elétrica              109  Mais de 100 anos
# 5           Petróleo e Gás               12  Menos de 50 anos
# 6           Petróleo e Gás               68    Entre 50 e 100
# 7                Mineração               79    Entre 50 e 100
# 8         Shopping Centers               48  Menos de 50 anos
# 9   Instituição Financeira               18  Menos de 50 anos
# 10                   Saúde               15  Menos de 50 anos
# 11                 Química               52    Entre 50 e 100
# 12        Transporte Aéreo               14  Menos de 50 anos
# 13          Petróleo e Gás                6  Menos de 50 anos
# 14        Energia Elétrica               25  Menos de 50 anos
# 15              Siderurgia               80    Entre 50 e 100
# 16                Educação               62    Entre 50 e 100
# 17       Indústria Química               84    Entre 50 e 100
# 18        Construção Civil               41  Menos de 50 anos
# 19         Moda e Calçados               50    Entre 50 e 100
# 20  Instituição Financeira               78    Entre 50 e 100
# 21     Alimentos e Bebidas               31  Menos de 50 anos
# 22     Alimentos e Bebidas               67    Entre 50 e 100
# 23     Alimentos e Bebidas               85    Entre 50 e 100
# 24        Telecomunicações               23  Menos de 50 anos
# 25  Transporte Ferroviário               13  Menos de 50 anos
# 26   Tecnologia Financeira               11  Menos de 50 anos
# 27              Tecnologia                7  Menos de 50 anos
# 28        Telecomunicações               29  Menos de 50 anos
# 29                 Holding               30  Menos de 50 anos
# 30              Tecnologia               25  Menos de 50 anos
# 31          Petróleo e Gás               16  Menos de 50 anos
# 32                 Holding               52    Entre 50 e 100
# 33  Instituição Financeira              213  Mais de 100 anos
# 34     Varejo Farmacêutico               25  Menos de 50 anos
# 35              Siderurgia              121  Mais de 100 anos
# 36     Energia e Logística               17  Menos de 50 anos
# 37     Alimentos e Bebidas               69    Entre 50 e 100
# 38                  Varejo               65    Entre 50 e 100
# 39  Instituição Financeira               78    Entre 50 e 100
# 40              Siderurgia              121  Mais de 100 anos
# 41                 Energia               11  Menos de 50 anos
# 42        Energia Elétrica               68    Entre 50 e 100
# 43               Logística                4  Menos de 50 anos

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#                   Segmento   Variacao_rs
# 0      Alimentos e Bebidas  414174599.32
# 1         Construção Civil   37525872.38
# 2                 Educação   72295838.99
# 3                  Energia   11571106.42
# 4         Energia Elétrica  682315640.01
# 5      Energia e Logística  127229653.18
# 6                  Holding  416092244.42
# 7        Indústria Química  388705223.96
# 8   Instituição Financeira 3740512018.78
# 9                Logística    4131341.16
# 10               Mineração 4940442965.55
# 11         Moda e Calçados   41021792.09
# 12        Papel e Celulose  722946282.71
# 13          Petróleo e Gás 6093288832.26
# 14                 Química   69054317.64
# 15                   Saúde  453917907.01
# 16        Shopping Centers  117732680.08
# 17              Siderurgia  489935930.93
# 18              Tecnologia   33667333.26
# 19   Tecnologia Financeira   43657683.38
# 20        Telecomunicações  292938114.42
# 21        Transporte Aéreo   65452205.55
# 22  Transporte Ferroviário  229771333.63
# 23                  Varejo   28493619.27
# 24     Varejo Farmacêutico  202352473.74

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 19719227010.14

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cafe9501-5009-4c30-bad6-7af0bccb9efe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cafe9501-5009-4c30-bad6-7af0bccb9efe")) {                    Plotly.newPlot(                        "cafe9501-5009-4c30-bad6-7af0bccb9efe",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,19719227010.14191],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,19719227010.14191],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}] ...
